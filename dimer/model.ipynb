# %% [markdown]
# # A Model for a coupled pair

# %% [markdown]
# A quantum master equation for a coupled pair of QDs is developed in this section. WE shall call the pair  The first assumption is that the quantum dots are identical.  This idealization makes the model much simpler.

# %% [markdown]
# ## The system Hamiltonian
#
# The individual QD has two energy levels, the ground state $|g\rangle$ and the excited state $|e\rangle$.  They are used as a basis set for the two-dimensional Hilbert space.  The pair
