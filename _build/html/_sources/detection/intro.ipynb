# %% [markdown]
# # Photon counting statistics

# %% [markdown]
# **To be completed**

# %% [markdown]
# In this chapter, a brief summary of the properties of light we want to investigate.  We begin with intensity mesurement of classical lights.  In particular, the temporal correlation of light intensity $g^(2)(\tau)$.  It will be shown that $g^(2)(0)$ must be bigger than 1.  However, experiments showed that it can be below 1 in violation of the lower bound obtained from the classical theory.  Only quantum mechanics can explain it.
#
# In quantum optics, experiments counts photons rather than measuring electric fields.  The statistics of photon counting replaces the classical analysis.  There are three
